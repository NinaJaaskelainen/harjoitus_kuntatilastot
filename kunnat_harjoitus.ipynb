# %%
import pandas as pd

# %%
df=pd.read_excel("kunnat.xlsx")
df
# Out:
#              Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0             Akaa                   88.5           16769
# 1         Alajärvi                   60.7            9831
# 2        Alavieska                   52.6            2610
# 3           Alavus                   59.5           11713
# 4         Asikkala                   64.4            8248
# 5           Askola                   53.2            4990
# 6             Aura                   69.9            3991
# 7           Brändö                    0.0             452
# 8           Eckerö                   41.8             948
# 9        Enonkoski                   39.9            1416
# 10       Enontekiö                   30.7            1893
# 11           Espoo                   99.5          279044
# 12            Eura                   72.3           11910
# 13        Eurajoki                   62.9            9521
# 14        Evijärvi                   35.7            2499
# ...

# %%
df[["Kunta", "Väkiluku, 2017"]].sort_values(by="Väkiluku, 2017", ascending=True).head(20)
# Out:
#              Kunta  Väkiluku, 2017
# 257       Sottunga              92
# 122          Kökar             236
# 113       Kumlinge             314
# 147     Lumparland             395
# 303          Vårdö             430
# 7           Brändö             452
# 18            Geta             495
# 17           Föglö             532
# 145        Luhanka             734
# 136     Lestijärvi             789
# 117        Kustavi             923
# 8           Eckerö             948
# 189  Pelkosenniemi             958
# 21        Hailuoto             967
# 242      Savukoski            1012
# 259           Sund            1031
# 154      Merijärvi            1119
# 99       Kivijärvi            1132
# 22          Halsua            1171
# 283        Utsjoki            1242

# %%
df[["Kunta", "Väkiluvun muutos edellisestä vuodesta, %, 2017"]][df["Väkiluvun muutos edellisestä vuodesta, %, 2017"]<1]
# Out:
#              Kunta  Väkiluvun muutos edellisestä vuodesta, %, 2017
# 0             Akaa                                            -0.9
# 1         Alajärvi                                            -0.7
# 2        Alavieska                                            -1.1
# 3           Alavus                                            -1.6
# 4         Asikkala                                            -0.9
# 5           Askola                                            -1.1
# 6             Aura                                             0.2
# 7           Brändö                                            -4.0
# 9        Enonkoski                                            -2.5
# 12            Eura                                            -0.8
# 14        Evijärvi                                            -1.4
# 15        Finström                                            -0.5
# 16          Forssa                                            -0.8
# ...

# %%
df.columns
# Out:
# Index(['Kunta', 'Taajama-aste, %, 2017', 'Väkiluku, 2017',
#        'Väkiluvun muutos edellisestä vuodesta, %, 2017',
#        'Alle 15-vuotiaiden osuus väestöstä, %, 2017',
#        '15-64 -vuotiaiden osuus väestöstä, %, 2017',
#        'Yli 64-vuotiaiden osuus väestöstä, %, 2017',
#        'Ruotsinkielisten osuus väestöstä, %, 2017',
#        'Ulkomaan kansalaisten osuus väestöstä, %, 2017',
#        'Syntyneiden enemmyys, henkilöä, 2017',
#        'Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017',
#        'Perheiden lukumäärä, 2017', 'Asuntokuntien lukumäärä, 2017',
#        'Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017',
#        'Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017',
#        'Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Alueella asuvan työllisen työvoiman määrä, 2016',
# ...

# %%
df.columns = ['Kunta', 'Taajama-aste', 'Väkiluku',
       'Väkiluvun muutos',
       'Alle 15-v',
       '15-64 -vuotiaiden osuus',
       'Yli 64-vuotiaiden osuus',
       'Ruotsinkielisten osuus',
       'Ulkomaan kansalaisten osuus',
       'Syntyneiden enemmyys',
       'muuttovoitto/-tappio',
       'Perheiden lukum', 'Asuntokuntien lukum',
       'Rivi- ja pientaloissa asuvat',
       'Vuokra-asunnoissa asuvat',
       'Vähintään toisen asteen tutk',
       'Korkea-asteen tutk',
       'työlliset',
       'Työllisyysaste',
       'Asuinkunnassa työssäkäyvät',
       'Tyött',
       'Eläkel',
       'Taloudellinen huoltosuhde',
       'työpaikkojen lukum',
       'Alkutuotannon työpaikk',
       'Jalostuksen työpaikk',
       'Palvelujen työpaikk',
       'Vuosikate', 'Lainakanta',
       'Konsernin lainakanta',
       'Opetus- ja kulttuuritoim',
       'Sosiaali- ja terveystoim']
df.columns
# Out:
# Index(['Kunta', 'Taajama-aste', 'Väkiluku', 'Väkiluvun muutos', 'Alle 15-v',
#        '15-64 -vuotiaiden osuus', 'Yli 64-vuotiaiden osuus',
#        'Ruotsinkielisten osuus', 'Ulkomaan kansalaisten osuus',
#        'Syntyneiden enemmyys', 'muuttovoitto/-tappio', 'Perheiden lukum',
#        'Asuntokuntien lukum', 'Rivi- ja pientaloissa asuvat',
#        'Vuokra-asunnoissa asuvat', 'Vähintään toisen asteen tutk',
#        'Korkea-asteen tutk', 'työlliset', 'Työllisyysaste',
#        'Asuinkunnassa työssäkäyvät', 'Tyött', 'Eläkel',
#        'Taloudellinen huoltosuhde', 'työpaikkojen lukum',
#        'Alkutuotannon työpaikk', 'Jalostuksen työpaikk', 'Palvelujen työpaikk',
#        'Vuosikate', 'Lainakanta', 'Konsernin lainakanta',
#        'Opetus- ja kulttuuritoim', 'Sosiaali- ja terveystoim'],
#       dtype='object')

# %%
df[["Kunta", "Väkiluvun muutos"]][df["Väkiluvun muutos"]<1].sort_values(by="Väkiluvun muutos", ascending=True).head(20)
# Out:
#           Kunta  Väkiluvun muutos
# 17        Föglö              -5.2
# 257    Sottunga              -4.2
# 122       Kökar              -4.1
# 7        Brändö              -4.0
# 22       Halsua              -3.9
# 68        Kaavi              -3.4
# 39   Hyrynsalmi              -3.3
# 204       Posio              -3.3
# 287       Vaala              -3.3
# 253       Soini              -3.3
# 192   Pertunmaa              -3.2
# 186   Parikkala              -3.1
# 242   Savukoski              -3.1
# 255  Sonkajärvi              -3.0
# 36    Honkajoki              -3.0
# 299  Viitasaari              -3.0
# 200    Pomarkku              -3.0
# 145     Luhanka              -2.9
# 258     Sulkava              -2.7
# 21     Hailuoto              -2.7
